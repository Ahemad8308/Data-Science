# %%
#  Data Wrangling  I

# %%
# Perform the Various operations using Python on any open source dataset

# %%
import pandas as pd

# %%
# Import pandas Python Libraries for data manipulation

# %%
 data = pd.read_excel('car_crash.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2133ce2c6695> in <cell line: 1>()
# ----> 1 data = pd.read_excel('car_crash.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
# Read the open source data
# The above dataset is contain the car_crash data which is from kaggle web site

# %%
data.info
# Out:
# <bound method DataFrame.info of        Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0      2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1      2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2      2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3      2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4      2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
# ...     ...    ...  ...      ...     ...            ...                 ...
# 53938  2003     10    6  Weekday  1700.0          2-Car   No injury/unknown
# 53939  2003     11    3  Weekday   800.0          1-Car   No injury/unknown
# 53940  2003     12    5  Weekday  1200.0          2-Car   No injury/unknown
# 53941  2003     12    1  Weekend   700.0          2-Car   No injury/unknown
# 53942  2003     12    7  Weekend  1700.0          2-Car  Non-incapacitating
#
# ...

# %%
# From above command we get the all information in dataset and it also give the information how many rows and column present in dataset

# %%
col=data.columns
print("The following Columns Present in Dataset")
print(col)
# Out:
# Index(['Year', 'Month', 'Day', 'Weekend?', 'Hour', 'Collision Type',
#        'Injury Type', 'Primary Factor', 'Reported_Location', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
# It gives the columns name present in dataset

# %%
data.shape
# Out:
# (53943, 11)

# %%
# It shows the number of rows and columns present in dataset
# Here 53943 rows and 11 columns present in dataset

# %%
data.dtypes
# Out:
# Year                   int64
# Month                  int64
# Day                    int64
# Weekend?              object
# Hour                 float64
# Collision Type        object
# Injury Type           object
# Primary Factor        object
# Reported_Location     object
# Latitude             float64
# Longitude            float64
# dtype: object

# %%
# It gives the datatypes of columns of given dataset
# There are following columns present
# 3 integer
# 3 float
# 5 object type

# %%
data.head()
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude
# 0 -86.525874
# 1 -86.534848
# 2 -86.568890
# 3 -86.575956
# ...

# %%
# It gives the first 5 rows of dataset

# %%
data.head(10)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
# 5  2015      1    6  Weekday  1800.0          2-Car   No injury/unknown
# 6  2015      1    6  Weekday  1200.0          2-Car   No injury/unknown
# 7  2015      1    6  Weekday  1400.0          1-Car      Incapacitating
# 8  2015      1    7  Weekend  1400.0          2-Car   No injury/unknown
# 9  2015      1    7  Weekend  1600.0          1-Car   No injury/unknown
#
#                              Primary Factor        Reported_Location  \
# 0     OTHER (DRIVER) - EXPLAIN IN NARRATIVE               1ST & FESS
# ...

# %%
#  we provide parameter to head therefore It gives the first 10 rows of dataset

# %%
data.tail()
# Out:
#        Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 53938  2003     10    6  Weekday  1700.0          2-Car   No injury/unknown
# 53939  2003     11    3  Weekday   800.0          1-Car   No injury/unknown
# 53940  2003     12    5  Weekday  1200.0          2-Car   No injury/unknown
# 53941  2003     12    1  Weekend   700.0          2-Car   No injury/unknown
# 53942  2003     12    7  Weekend  1700.0          2-Car  Non-incapacitating
#
#                               Primary Factor      Reported_Location  Latitude  \
# 53938                    IMPROPER LANE USAGE  DUNN & WHITE LOT WEST       0.0
# 53939                           UNSAFE SPEED        RED OAK & SR446       0.0
# 53940             BRAKE FAILURE OR DEFECTIVE        2ND ST & WALNUT       0.0
# 53941                         UNSAFE BACKING         NINETH & NORTH       0.0
# 53942  OTHER (DRIVER) - EXPLAIN IN NARRATIVE      MONROW & THIRD ST       0.0
#
#        Longitude
# 53938        0.0
# ...

# %%
# It gives the last 5 rows of dataset

# %%
data.tail(10)
# Out:
#        Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 53933  2003      9    2  Weekday   900.0          2-Car  Non-incapacitating
# 53934  2003     10    1  Weekday  2100.0          2-Car   No injury/unknown
# 53935  2003     10    3  Weekday  1900.0          2-Car   No injury/unknown
# 53936  2003     10    4  Weekday  1700.0          1-Car  Non-incapacitating
# 53937  2003     10    5  Weekday  1800.0          2-Car   No injury/unknown
# 53938  2003     10    6  Weekday  1700.0          2-Car   No injury/unknown
# 53939  2003     11    3  Weekday   800.0          1-Car   No injury/unknown
# 53940  2003     12    5  Weekday  1200.0          2-Car   No injury/unknown
# 53941  2003     12    1  Weekend   700.0          2-Car   No injury/unknown
# 53942  2003     12    7  Weekend  1700.0          2-Car  Non-incapacitating
#
#                               Primary Factor                Reported_Location  \
# ...

# %%
# we provide parameter to tail therefore It gives the last 10 rows of dataset

# %%
data.isnull()
# Out:
#         Year  Month    Day  Weekend?   Hour  Collision Type  Injury Type  \
# 0      False  False  False     False  False           False        False
# 1      False  False  False     False  False           False        False
# 2      False  False  False     False  False           False        False
# 3      False  False  False     False  False           False        False
# 4      False  False  False     False  False           False        False
# ...      ...    ...    ...       ...    ...             ...          ...
# 53938  False  False  False     False  False           False        False
# 53939  False  False  False     False  False           False        False
# 53940  False  False  False     False  False           False        False
# 53941  False  False  False     False  False           False        False
# 53942  False  False  False     False  False           False        False
#
#        Primary Factor  Reported_Location  Latitude  Longitude
# ...

# %%
# If there is any null value present in data then it gives True
# Otherwise it gives False

# %%
data.describe()
# Out:
#                Year         Month           Day          Hour      Latitude  \
# count  53943.000000  53943.000000  53943.000000  53718.000000  53913.000000
# mean    2008.968059      6.662162      4.196912   1347.265349     35.582109
# std        3.789760      3.514630      1.909440    531.654039     11.289883
# min     2003.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2006.000000      4.000000      3.000000   1000.000000     39.142048
# 50%     2009.000000      7.000000      4.000000   1400.000000     39.164430
# 75%     2012.000000     10.000000      6.000000   1700.000000     39.173344
# max     2015.000000     12.000000      7.000000   2300.000000     41.228665
#
#           Longitude
# count  53913.000000
# mean     -78.619224
# std       24.957587
# min      -88.959213
# 25%      -86.551520
# 50%      -86.530992
# 75%      -86.508288
# max       86.596363

# %%
df_weekend = pd.get_dummies(data['Weekend?'])

df_new = pd.concat([data, df_weekend], axis=1)

print(df_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-523856219fb6> in <cell line: 1>()
# ----> 1 df_weekend = pd.get_dummies(df['Weekend?'])
#       2
#       3 df_new = pd.concat([df, df_weekend], axis=1)
#       4
#       5 print(df_new)
#
# NameError: name 'pd' is not defined

# %%
# It gives the Statistical information of our Dataset
# like mean, count, minimum value, maximum values of numerical datatype columns
